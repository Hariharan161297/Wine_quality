# %% [markdown]
# # Problem statement

# %% [markdown]
# This project aims to analyse the wine dataset and used for predicting the wine “good quality” or not from the past historical data.
#
# This problem statement comes under the category of Supervised classification machine learning algorithm.

# %% [markdown]
# # Importing Libraries

# %%
#import necessary libraries
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Loading Dataset

# %%
wine = pd.read_csv("winequality-red.csv")
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
print(wine.shape)
# Out:
# (1599, 12)

# %% [markdown]
# # Data cleaning
#
# ### fixed acidity

# %%
wine["fixed acidity"].dtype
# Out:
# dtype('float64')

# %%
wine["fixed acidity"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["fixed acidity"].quantile(0.75)
q1 = wine["fixed acidity"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)
upper_threshold, lower_threshold
# Out:
# (12.349999999999998, 3.95)

# %%
wine["fixed acidity"].describe()
# Out:
# count    1599.000000
# mean        8.166354
# std         1.411762
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        10.500000
# Name: fixed acidity, dtype: float64

# %%
wine["fixed acidity"] = wine["fixed acidity"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### volatile acidity

# %%
wine["volatile acidity"].dtype
# Out:
# dtype('float64')

# %%
wine["volatile acidity"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["volatile acidity"].quantile(0.75)
q1 = wine["volatile acidity"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (1.0150000000000001, 0.015000000000000013)

# %%
wine["volatile acidity"].describe()
# Out:
# count    1599.000000
# mean        0.527821
# std         0.179060
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
wine["volatile acidity"] = wine["volatile acidity"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### citric acid

# %%
wine["citric acid"].dtype
# Out:
# dtype('float64')

# %%
wine["citric acid"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["citric acid"].quantile(0.75)
q1 = wine["citric acid"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (0.9149999999999999, -0.4049999999999999)

# %%
wine["citric acid"].describe()
# Out:
# count    1599.000000
# mean        0.270976
# std         0.194801
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
wine["citric acid"] = wine["citric acid"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### residual sugar

# %%
wine["residual sugar"].dtype
# Out:
# dtype('float64')

# %%
wine["residual sugar"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["residual sugar"].quantile(0.75)
q1 = wine["residual sugar"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (3.4000000000000004, 0.9999999999999998)

# %%
wine["residual sugar"].describe()
# Out:
# count    1599.000000
# mean        2.146216
# std         0.334499
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.500000
# max         2.500000
# Name: residual sugar, dtype: float64

# %%
wine["residual sugar"] = wine["residual sugar"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### chlorides

# %%
wine["chlorides"].dtype
# Out:
# dtype('float64')

# %%
wine["chlorides"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["chlorides"].quantile(0.75)
q1 = wine["chlorides"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (0.11999999999999998, 0.04000000000000002)

# %%
wine["chlorides"].describe()
# Out:
# count    1599.000000
# mean        0.087467
# std         0.047065
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
wine["chlorides"] = wine["chlorides"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### free sulfur dioxide

# %%
wine["free sulfur dioxide"].dtype
# Out:
# dtype('float64')

# %%
wine["free sulfur dioxide"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["free sulfur dioxide"].quantile(0.75)
q1 = wine["free sulfur dioxide"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (42.0, -14.0)

# %%
wine["free sulfur dioxide"].describe()
# Out:
# count    1599.000000
# mean       14.343027
# std         7.403493
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        25.000000
# Name: free sulfur dioxide, dtype: float64

# %%
wine["free sulfur dioxide"] = wine["free sulfur dioxide"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### total sulfur dioxide

# %%
wine["total sulfur dioxide"].dtype
# Out:
# dtype('float64')

# %%
wine["total sulfur dioxide"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["total sulfur dioxide"].quantile(0.75)
q1 = wine["total sulfur dioxide"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (97.0, -23.0)

# %%
wine["total sulfur dioxide"].describe()
# Out:
# count    1599.000000
# mean       35.758599
# std        15.147477
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        52.000000
# max        52.000000
# Name: total sulfur dioxide, dtype: float64

# %%
wine["total sulfur dioxide"] = wine["total sulfur dioxide"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### density

# %%
wine["density"].dtype
# Out:
# dtype('float64')

# %%
wine["density"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["density"].quantile(0.75)
q1 = wine["density"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (1.0011875, 0.9922475000000001)

# %%
wine["density"].describe()
# Out:
# count    1599.000000
# mean        0.996747
# std         0.001887
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997835
# max         1.003690
# Name: density, dtype: float64

# %% [markdown]
# ### pH

# %%
wine["pH"].dtype
# Out:
# dtype('float64')

# %%
wine["pH"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["pH"].quantile(0.75)
q1 = wine["pH"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (3.6849999999999996, 2.925)

# %%
wine["pH"].describe()
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
wine["pH"] = wine["pH"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### sulphates

# %%
wine["sulphates"].dtype
# Out:
# dtype('float64')

# %%
wine["sulphates"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["sulphates"].quantile(0.75)
q1 = wine["sulphates"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (0.9999999999999999, 0.28000000000000014)

# %%
wine["sulphates"].describe()
# Out:
# count    1599.000000
# mean        0.658149
# std         0.169507
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
wine["sulphates"] = wine["sulphates"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### alcohol

# %%
wine["alcohol"].dtype
# Out:
# dtype('float64')

# %%
wine["alcohol"].isnull().sum()
# Out:
# 0

# %%
q3 = wine["alcohol"].quantile(0.75)
q1 = wine["alcohol"].quantile(0.25)
iqr = q3 - q1

upper_threshold = q3 + (1.5 * iqr) 
lower_threshold = q1 - (1.5 * iqr)

upper_threshold, lower_threshold
# Out:
# (13.5, 7.1000000000000005)

# %%
wine["alcohol"].describe()
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
wine["alcohol"] = wine["alcohol"].clip(lower_threshold, upper_threshold)

# %% [markdown]
# ### quality

# %%
wine["quality"].dtype
# Out:
# dtype('int64')

# %%
wine["quality"].isnull().sum()
# Out:
# 0

# %%
wine.duplicated().sum()
# Out:
# 243

# %%
wine.drop_duplicates(keep="first",inplace=True)

# %% [markdown]
# # Feature transformation

# %%
wine['goodquality'] = [1 if x >= 6 else 0 for x in wine['quality']]# Separate feature variables and target variable
wine.drop('quality', axis = 1,inplace=True)

# %% [markdown]
# # EDA

# %%
wine['goodquality'].value_counts()
# Out:
# 1    717
# 0    639
# Name: goodquality, dtype: int64

# %%
sns.countplot(data=wine, x='goodquality')
plt.show()

# %%
# Setting up subplots
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(18, 12))
axes = axes.flatten()

# Plotting bar charts for each column against 'goodquality'
for i, column in enumerate(wine.columns[:-1]):  # Excluding the last column which is 'goodquality'
    sns.barplot(x='goodquality', y=column, data=wine, ax=axes[i])
    axes[i].set_title(column)

plt.tight_layout()
plt.show()

# %%
#Density plots are a way to visualize the distribution of a continuous variable.
wine.plot(kind ='density',subplots = True, layout =(4,3),sharex = False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# We can see that more or less all columns are symmetrically distributed(no skewness)

# %% [markdown]
# ### Heatmap for expressing correlation

# %%
plt.figure(figsize=(10,8))
corr = wine.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X = wine.drop(['goodquality'], axis = 1)
Y = wine['goodquality']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # LogisticRegression:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,classification_report, roc_curve, auc
print("Training Score:",model.score(X_train, Y_train))
print("Testing Score:",model.score(X_test, Y_test))
# Out:
# Training Score: 0.8829311885612153
# Testing Score: 0.8729166666666667

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       417
#            1       0.53      0.30      0.38        63
#
#     accuracy                           0.87       480
#    macro avg       0.71      0.63      0.66       480
# weighted avg       0.85      0.87      0.86       480

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[400  17]
#  [ 44  19]]

# %% [markdown]
# # Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Training Score:",model.score(X_train, Y_train))
print("Testing Score:",model.score(X_test, Y_test))
# Out:
# Training Score: 0.9231456657730116
# Testing Score: 0.85625

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       417
#            1       0.45      0.40      0.42        63
#
#     accuracy                           0.86       480
#    macro avg       0.68      0.66      0.67       480
# weighted avg       0.85      0.86      0.85       480

# %%
confusion_mat = confusion_matrix(Y_test,y_pred)
print(confusion_mat)
# Out:
# [[386  31]
#  [ 38  25]]

# %% [markdown]
# # Using Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Training Score:",model.score(X_train, Y_train))
print("Testing Score:",model.score(X_test, Y_test))
# Out:
# Training Score: 1.0
# Testing Score: 0.8354166666666667

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       417
#            1       0.40      0.54      0.46        63
#
#     accuracy                           0.84       480
#    macro avg       0.67      0.71      0.68       480
# weighted avg       0.86      0.84      0.85       480

# %%
confusion_mat = confusion_matrix(Y_test,y_pred)
print(confusion_mat)
# Out:
# [[367  50]
#  [ 29  34]]

# %% [markdown]
# # Using Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)


from sklearn.metrics import accuracy_score
print("Training Score:",model2.score(X_train, Y_train))
print("Testing Score:",model2.score(X_test, Y_test))
# Out:
# Training Score: 1.0
# Testing Score: 0.89375

# %%
print(classification_report(Y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       417
#            1       0.62      0.51      0.56        63
#
#     accuracy                           0.89       480
#    macro avg       0.77      0.73      0.75       480
# weighted avg       0.89      0.89      0.89       480

# %%
confusion_mat = confusion_matrix(Y_test,y_pred2)
print(confusion_mat)
# Out:
# [[397  20]
#  [ 31  32]]

# %%
# ROC curve and AUC
fpr, tpr, thresholds = roc_curve(Y_test, y_pred2)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'm-')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.2])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
print (pd.DataFrame(model2.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                            Imp
# fixed acidity         0.065728
# volatile acidity      0.128490
# citric acid           0.081745
# residual sugar        0.039017
# chlorides             0.083007
# free sulfur dioxide   0.055967
# total sulfur dioxide  0.082392
# density               0.099735
# pH                    0.068996
# sulphates             0.118576
# alcohol               0.176347

# %% [markdown]
# # Using Xgboost:

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred5 = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Training Score:",model.score(X_train, Y_train))
print("Testing Score:",model.score(X_test, Y_test))
# Out:
# Training Score: 1.0
# Testing Score: 0.8354166666666667

# %%
print(classification_report(Y_test, y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       417
#            1       0.61      0.59      0.60        63
#
#     accuracy                           0.90       480
#    macro avg       0.77      0.76      0.77       480
# weighted avg       0.89      0.90      0.90       480

# %%
confusion_mat = confusion_matrix(Y_test,y_pred5)
print(confusion_mat)
# Out:
# [[393  24]
#  [ 26  37]]

# %% [markdown]
# ### Comparing all the models to choose the best performing model

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN','Decision Tree','Random Forest','Xgboost'],
    'Score': [0.872,0.856,0.835,0.893,0.835]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 0.893        Random Forest
# 0.872  Logistic Regression
# 0.856                  KNN
# 0.835        Decision Tree
# 0.835              Xgboost

# %%
When comparing the all models Random Forest performs better

# %% [markdown]
# Hence I will use Random Forest algorithms for training my model.
#
# I have created a streamlit application that allows the user to enter the paramters of wine and can able to check the quality of wine is good or not.

# %% [markdown]
# ### Saving Model

# %%
import pickle

# %%
pickle.dump(model2, open('wine_model.pkl','wb'))

# %% [markdown]
# # conclusion

# %% [markdown]
# I have developed a machine learning-based web application that wine researchers and wine growers can use to predict wine quality based on the important available chemical compounds in their wines
